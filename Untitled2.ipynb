# %% [markdown]
# <a href="https://colab.research.google.com/github/deepikaruparaju3/SE-lab/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def Temperature_modeling(a,b,c,time):
  temperature=a*time**2+b*time+c
  return temperature

# %%
#hard coded variables
a,b,c=0.5,2,10
time=3

# %%
#Display Results
print("Hard-coded variables for weather modeling")
print("Temperature for hard coded coefficients at time",time,"hours:",Temperature_modeling(a,b,c,time))
# Out:
# Hard-coded variables for weather modeling
# Temperature for hard coded coefficients at time 3 hours: 20.5

# %%
a=float(input("Enter coefficient a:"))
b=float(input("Enter coefficient b:"))
c=float(input("Enter coefficient c:"))
time=float(input("Enter time:"))
# Out:
# Enter coefficient a:0.5
# Enter coefficient b:2
# Enter coefficient c:10
# Enter time:3

# %%
#variables read from keyboard
print("Variables read from keyboard for weather modeling")
print("Temperature for given coefficients at time",time,"hours:",Temperature_modeling(a,b,c,time))
# Out:
# Variables read from keyboard for weather modeling
# Temperature for given coefficients at time 3.0 hours: 20.5

# %%
#Read coefficients from a file
def read_from_file(filename):
  with open(filename,'r') as file:
    lines=file.readlines()
  coefficients=[tuple(map(float,line.strip().split(',')))for line in lines]
  return coefficients

# %%
#Exmaple: Solve for a single set of inputs
coefficients=read_from_file('/content/variables.txt')
a,b,c,time=coefficients[0]
temperature=Tempertaure_modeling(a,b,c,time)
print("Read from a file coefficients for weather modeling")
print("Temperature for given coefficients at time",time,"hours:",Temperature_modeling(a,b,c,time))
# Out:
#   File "<ipython-input-15-ae3b28f8cf93>", line 2
#     coefficients=read_from_file('C:\Users\H-CSE-404-15\Desktop\content\variables.txt')
#                                                                                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
def Temperature_modeling(a, b, c, time):
    # Example formula for temperature modeling (can be modified)
    temperature = a * time**2 + b * time + c
    return temperature

def read_from_file(file_path):
    with open(file_path, 'r') as file:
        data = file.read().strip().split()
        return list(map(float, data))  # Convert to a list of floats

# Read coefficients from the file
coefficients = read_from_file('variables.txt')
a, b, c, time = coefficients

# Calculate the temperature using the model
temperature = Temperature_modeling(a, b, c, time)

print("Read from a file coefficients for weather modeling:")
print("Temperature for given coefficients at time", time, "hours:", temperature)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-b12926b89a31> in <cell line: 0>()
#      10
#      11 # Read coefficients from the file
# ---> 12 coefficients = read_from_file('variables.txt')
#      13 a, b, c, time = coefficients
#      14
#
# <ipython-input-16-b12926b89a31> in read_from_file(file_path)
#       5
#       6 def read_from_file(file_path):
# ----> 7     with open(file_path, 'r') as file:
#       8         data = file.read().strip().split()
#       9         return list(map(float, data))  # Convert to a list of floats
#
# FileNotFoundError: [Errno 2] No such file or directory: 'variables.txt'

# %%
def Temperature_modeling(a, b, c, time):
        # Example formula for temperature modeling (can be modified)
        temperature = a * time**2 + b * time + c
        return temperature

def read_from_file(file_path):
        # Check if the file exists before opening
        import os  # Import the os module
        if not os.path.exists(file_path):
            # If file not found, create it with default values and alert the user
            with open(file_path, 'w') as file:
                file.write("0.5, 2, 10, 3")  # Default values for a, b, c, time
            print(f"File '{file_path}' not found. Created with default values: 0.5, 2, 10, 3")

        with open(file_path, 'r') as file:
            data = file.read().strip().split()  # Read data from file
            return list(map(float, data))  # Convert data to float

    # Read coefficients from the file
coefficients = read_from_file('variables.txt')
a, b, c, time = coefficients

    # Calculate the temperature using the model
temperature = Temperature_modeling(a, b, c, time)

print("Read from a file coefficients for weather modeling:")
print("Temperature for given coefficients at time", time, "hours:", temperature)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-41332e5bd44e> in <cell line: 0>()
#      18
#      19     # Read coefficients from the file
# ---> 20 coefficients = read_from_file('variables.txt')
#      21 a, b, c, time = coefficients
#      22
#
# <ipython-input-25-41332e5bd44e> in read_from_file(file_path)
#      15         with open(file_path, 'r') as file:
#      16             data = file.read().strip().split()  # Read data from file
# ---> 17             return list(map(float, data))  # Convert data to float
#      18
#      19     # Read coefficients from the file
#
# ValueError: could not convert string to float: '0.5,'
